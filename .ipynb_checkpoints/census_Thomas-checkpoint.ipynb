# %%
# Dependencies
import json
import requests
import pandas as pd

# %%
api_key = '3286c138a388ef8b9e598517a438a480860463e3'

# %%
#Vacant housing units = B25004_001E, 
# median home value = B25077_001E
# median year structures built = B25035_001E
url = 'https://api.census.gov/data/2013/acs1?get=NAME,B01003_001E,B25004_001E,B25077_001E,B25035_001E,B10010_001E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*&key='
#url = 'https://api.census.gov/data/2016/acs1?get=*&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*&key='

#FORS
#metropolitan%20statistical%20area/micropolitan%20statistical%20area
#state
#congressional%20district

key_url = url + api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adbf9d38a6e6> in <module>()
#      10 #congressional%20district
#      11
# ---> 12 key_url = url + api_key
#
# NameError: name 'api_key' is not defined

# %%
#base_url = 'https://api.census.gov/data/'
#year = '2016/'
#datasetAcronym = 'acs1/'
#query = '?get='

#full_url = base_url + year + datasetAcronym

#https://api.census.gov/data/2013/acs1?get=NAME,B02015_009E,B02015_009M&for=state:*&key=your key here

columns = {'NAME': 'Name of Metro Area',
            'B01003_001E' : 'Total Population',
            'B25004_001E' : 'Vacant Housing Units',
            'B25077_001E' : 'Median Home Value',
            'B25035_001E' : 'Median Year Sructures Built',
            'metropolitan statistical area/micropolitan statistical area' : 'Area ID'
          }

# %%
census_response = requests.get(key_url)
census_json = census_response.json()

dataFrame =pd.DataFrame(census_json)
dataFrame.columns = dataFrame.iloc[0]
dataFrame = dataFrame.drop([0])
dataFrame = dataFrame.rename(columns=columns)

# %%
dataFrame
# Out:
# 0                                   Name of Metro Area Total Population  \
# 1                     Aguadilla-Isabela, PR Metro Area           327847
# 2                               Arecibo, PR Metro Area           195036
# 3                               Guayama, PR Metro Area            81217
# 4                              Mayagüez, PR Metro Area           101856
# 5                                 Ponce, PR Metro Area           333527
# 6                            San Germán, PR Metro Area           134623
# 7              San Juan-Carolina-Caguas, PR Metro Area          2288977
# 8                              Aberdeen, WA Micro Area            71078
# 9                               Abilene, TX Metro Area           168144
# 10                               Adrian, MI Micro Area            99188
# 11                                Akron, OH Metro Area           705686
# 12                           Alamogordo, NM Micro Area            65616
# 13                               Albany, GA Metro Area           156277
# 14                               Albany, OR Metro Area           118765
# 15              Albany-Schenectady-Troy, NY Metro Area           877905
# 16                          Albertville, AL Micro Area            94760
# 17                          Albuquerque, NM Metro Area           901932
# 18                           Alexandria, LA Metro Area           154753
# 19        Allentown-Bethlehem-Easton, PA-NJ Metro Area           827048
# 20                              Altoona, PA Metro Area           126314
# 21                             Amarillo, TX Metro Area           259164
# 22                                 Ames, IA Metro Area            92406
# 23                            Anchorage, AK Metro Area           396142
# 24                            Ann Arbor, MI Metro Area           354240
# 25         Anniston-Oxford-Jacksonville, AL Metro Area           116736
# 26                             Appleton, WI Metro Area           229962
# 27                            Asheville, NC Metro Area           437657
# 28                            Ashtabula, OH Micro Area            99811
# 29                               Athens, TX Micro Area            78675
# 30                 Athens-Clarke County, GA Metro Area           197357
# ..                                                 ...              ...
# 486                 Visalia-Porterville, CA Metro Area           454143
# 487                                Waco, TX Metro Area           257083
# 488                         Walla Walla, WA Metro Area            63361
# 489                       Warner Robins, GA Metro Area           185623
# 490                              Warsaw, IN Micro Area            77963
# 491  Washington-Arlington-Alexandria, DC-VA-MD-WV M...          5950214
# 492                Waterloo-Cedar Falls, IA Metro Area           169484
